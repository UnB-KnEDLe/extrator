# %%
from dodfminer.extract.pure.core import ContentExtractor
from dodfminer.extract.polished.core import ActsExtractor

# %%
ContentExtractor.extract_text('/home/vitor/Development/knedle/DODFMiner/dodfminer/extract/polished/contract/contrato3.pdf', single=True, block=False, sep='\n<>END OF BLOCK<>\n')

# %%
dframe = ActsExtractor.get_act_df('contratos', '/home/vitor/Development/knedle/DODFMiner/dodfminer/extract/polished/contract/contrato3.txt', 'regex')

# %%
dframe
# Out:
#    Tipo do Ato  Contrato          Processo Data de Assinatura  \
# 0     Contrato   57/2012  133.000.274/2012                NaN
# 1     Contrato   58/2012  133.000.274/2012                NaN
# 2     Contrato   07/2012  134.000.930/2012         28/12/2012
# 3     Contrato   47/2012  138.001.792/2012                NaN
# 4     Contrato   21/2012  139.000.635/2012                NaN
# 5     Contrato   21/2012  139.000.129/2012                NaN
# 6     Contrato   07/2012  306.000.061/2012                NaN
# 7     Contrato   08/2012  306.000.229/2012                NaN
# 8     Contrato   09/2012  306.000.057/2012                NaN
# 9     Contrato  519/2012  150.003.491/2012                NaN
# 10    Contrato  520/2012  150.003.499/2012                NaN
# 11    Contrato   41/2012  040.000.671/2012                NaN
# 12    Contrato   42/2012  040.000.671/2012         18/12/2012
# 13    Contrato   43/2012  040.000.671/2012         21/12/2012
# ...

# %%
dframe['Contrato'][0]
# Out:
# '57/2012'
